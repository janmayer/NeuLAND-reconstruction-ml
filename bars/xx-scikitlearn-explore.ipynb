# %% [markdown]
# # Multiplicity determination with Scikit-learn classifiers

# %% [markdown]
# Here we test out scikit-learn classification models for multiplicity reconstruction with the three main features number of hits, number of clusters, and total deposited energy.

# %%
import numpy as np
import pandas as pd
import h5py
import time
import multiprocessing
import functools
from joblib import Parallel, delayed

import sklearn
from sklearn import *
from sklearn.experimental import enable_hist_gradient_boosting

# %% [markdown]
# Load ALL the classification models from scikit-learn.
# Note that some models are very slow to train with large datasets or crash outright, so we give them a reduced number of (shuffled) rows to learn.
# Note that `n_jobs=1` is used, as parallelism is introduced later.

# %%
models_a1 = [
    ('BaggingClassifier', sklearn.ensemble.BaggingClassifier(n_jobs=1), 'medi'),
    ('BernoulliNB', sklearn.naive_bayes.BernoulliNB(), 'fast'),
    ('CalibratedClassifierCV', sklearn.calibration.CalibratedClassifierCV(cv=5), 'slow'),
    ('ComplementNB', sklearn.naive_bayes.ComplementNB(), 'fast'),
    ('GaussianNB', sklearn.naive_bayes.GaussianNB(), 'fast'),
]

models_a2 = [
    ('LinearDiscriminantAnalysis', sklearn.discriminant_analysis.LinearDiscriminantAnalysis(), 'fast'),
    ('LinearSVC', sklearn.svm.LinearSVC(max_iter=20000), 'slow'),  # slow with unscaled data
    ('LogisticRegression', sklearn.linear_model.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=20000), 'slow'),  # slow with unscaled data
    ('LogisticRegressionCV', sklearn.linear_model.LogisticRegressionCV(cv=5, solver='lbfgs', multi_class='auto', max_iter=20000), 'slow'),
    ('MLPClassifier', sklearn.neural_network.MLPClassifier(), 'slow'),
    ('MultinomialNB', sklearn.naive_bayes.MultinomialNB(), 'fast'),
]

models_b = [
    ('NearestCentroid', sklearn.neighbors.NearestCentroid(), 'fast'),
    ('PassiveAggressiveClassifier', sklearn.linear_model.PassiveAggressiveClassifier(max_iter=1000, tol=1e-3, n_jobs=1), 'fast'),
    ('Perceptron', sklearn.linear_model.Perceptron(n_jobs=1), 'fast'),
    ('QuadraticDiscriminantAnalysis', sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis(), 'fast'),
    ('RidgeClassifier', sklearn.linear_model.RidgeClassifier(), 'fast'),
    ('RidgeClassifierCV', sklearn.linear_model.RidgeClassifierCV(), 'fast'),
    ('SGDClassifier', sklearn.linear_model.SGDClassifier(max_iter=5000, tol=1e-3, n_jobs=1), 'medi'),

]

# Run these sequential due to "buffer source array is read-only" with LokyBackend
models_s = [
    ('AdaBoostClassifier', sklearn.ensemble.AdaBoostClassifier(), 'fast'),
    ('DecisionTreeClassifier', sklearn.tree.DecisionTreeClassifier(), 'medi'),    
    ('ExtraTreeClassifier', sklearn.tree.ExtraTreeClassifier(), 'fast'),
    ('ExtraTreesClassifier', sklearn.ensemble.ExtraTreesClassifier(n_estimators=100, n_jobs=-1), 'medi'),
    ('RandomForestClassifier', sklearn.ensemble.RandomForestClassifier(n_estimators=100, n_jobs=-1), 'medi'),
]

# Models that fail alot
models_o = [
    # ('NuSVC', sklearn.svm.NuSVC(), 'fast'),  # nu infeasible 
    ('RadiusNeighborsClassifier', sklearn.neighbors.RadiusNeighborsClassifier(radius=3, n_jobs=-1), 'medi'),
    ('GaussianProcessClassifier', sklearn.gaussian_process.GaussianProcessClassifier(), 'slow'),
    # ('GradientBoostingClassifier', sklearn.ensemble.GradientBoostingClassifier(), 'slow'),  # crashes
    # ('HistGradientBoostingClassifier', sklearn.ensemble.HistGradientBoostingClassifier(), 'slow'),  # crashes? 
    ('KNeighborsClassifier', sklearn.neighbors.KNeighborsClassifier(n_jobs=10), 'slow'),
    ('LabelPropagation', sklearn.semi_supervised.LabelPropagation(), 'slow'),  # requires too much memory to train with larger datasets
    ('LabelSpreading', sklearn.semi_supervised.LabelSpreading(), 'slow'),  # bit slow
    ('SVC', sklearn.svm.SVC(gamma='scale'), 'slow'), # slow, not timeouted 
]

# %% [markdown]
# Some models only work with properly scaled data, so we prepare ALL available scalers.

# %%
scalers = [
    # ('Unscaled data', ),
    ('standard scaling', sklearn.preprocessing.StandardScaler()),
    ('min-max scaling', sklearn.preprocessing.MinMaxScaler()),
    ('max-abs scaling', sklearn.preprocessing.MaxAbsScaler()),
    ('robust scaling', sklearn.preprocessing.RobustScaler(quantile_range=(25, 75))),
    ('power transformation (Yeo-Johnson)', sklearn.preprocessing.PowerTransformer(method='yeo-johnson')),
    # ('power transformation (Box-Cox)', sklearn.preprocessing.PowerTransformer(method='box-cox')), # 'strictly zero' meh.
    ('quantile transformation (gaussian pdf)', sklearn.preprocessing.QuantileTransformer(output_distribution='normal')),
    ('quantile transformation (uniform pdf)', sklearn.preprocessing.QuantileTransformer(output_distribution='uniform')),
    ('sample-wise L2 normalizing', sklearn.preprocessing.Normalizer()),
]

# %% [markdown]
# Train and Test data is passed through the scalers, including the "unscaled" scaler.

# %%
num_dp = 30

infile = f"data/600AMeV_{num_dp}dp.bars-shuffled.h5"
h5in = h5py.File(infile, "r")
x = np.array(h5in["flatfeatures"][0:100000], dtype=np.float32)
y = np.array(h5in["multiplicity"][0:100000, 2], dtype=np.int8)

# %%
x_scalers = {"Unscaled data": x}
for sname, scaler in scalers:
    x_scalers[sname] = scaler.fit_transform(x)
# Out:
# /home/jmayer/.local/share/virtualenvs/FutureReco2-AsCagFYD/lib/python3.7/site-packages/numpy/core/_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/jmayer/.local/share/virtualenvs/FutureReco2-AsCagFYD/lib/python3.7/site-packages/numpy/core/_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
x_scalers_split = {}
for sname, scaler in x_scalers.items():
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(
        x_scalers[sname], y, test_size=0.2
    )
    x_scalers_split[sname] = (x_train, x_test, y_train, y_test)

# %% [markdown]
# Run all model/scaler combinations, in parallel. Note that we use timeouts per task, as setting at timeout in joblib will throw everything.

# %%
def with_timeout(timeout):
    def decorator(decorated):
        @functools.wraps(decorated)
        def inner(*args, **kwargs):
            pool = multiprocessing.pool.ThreadPool(1)
            async_result = pool.apply_async(decorated, args, kwargs)
            try:
                return async_result.get(timeout)
            except multiprocessing.TimeoutError:
                return

        return inner

    return decorator

# %%
MEDIHEAD = 10000
SLOWHEAD = 1000


@with_timeout(3000)
def train_model(mname, modelorg, speed, sname, data):
    try:
        x_train, x_test, y_train, y_test = data
        model = sklearn.base.clone(modelorg)
        start = time.time()
        if speed == "slow":
            model.fit(x_train[0:SLOWHEAD], y_train[0:SLOWHEAD])
        elif speed == "medi":
            model.fit(x_train[0:MEDIHEAD], y_train[0:MEDIHEAD])
        elif speed == "fast":
            model.fit(x_train, y_train)
        end = time.time()

        y_pred = model.predict(x_test)
        y_true = y_test

        bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)
        return (mname, sname, bac, speed, (end - start), "ok")
    except Exception as err:
        return (mname, sname, np.NaN, speed, np.NaN, err)


def train_model_wrap(mname, modelorg, speed, sname, data):
    print(mname, sname)
    ret = train_model(mname, modelorg, speed, sname, data)
    if ret:
        print(ret)
        return ret
    else:
        return (mname, sname, np.NaN, speed, np.NaN, "Timeout")

# %%
try:
    results_a1 = Parallel(n_jobs=10, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, data)
        for mname, modelorg, speed in models_a1
        for sname, data in x_scalers_split.items()
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=10)]: Done  54 out of  54 | elapsed:  8.8min finished

# %%
try:
    results_a2 = Parallel(n_jobs=10, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, data)
        for mname, modelorg, speed in models_a2
        for sname, data in x_scalers_split.items()
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=10)]: Done  54 out of  54 | elapsed: 36.7min finished

# %%
try:
    results_b = Parallel(n_jobs=10, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, data)
        for mname, modelorg, speed in models_b
        for sname, data in x_scalers_split.items()
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done  30 tasks      | elapsed: 11.6min
# /home/jmayer/.local/share/virtualenvs/FutureReco2-AsCagFYD/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=10)]: Done  63 out of  63 | elapsed: 42.2min finished

# %%
try:
    results_s = Parallel(n_jobs=1, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, data)
        for mname, modelorg, speed in models_s
        for sname, data in x_scalers_split.items()
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# AdaBoostClassifier Unscaled data
# ('AdaBoostClassifier', 'Unscaled data', 0.2843571933549634, 'fast', 518.7534177303314, 'ok')
# AdaBoostClassifier standard scaling
# ('AdaBoostClassifier', 'standard scaling', 0.2805385624827795, 'fast', 484.35504055023193, 'ok')
# AdaBoostClassifier min-max scaling
# ('AdaBoostClassifier', 'min-max scaling', 0.26770355228655024, 'fast', 475.6151866912842, 'ok')
# AdaBoostClassifier max-abs scaling
# ('AdaBoostClassifier', 'max-abs scaling', 0.27805130079086665, 'fast', 461.894330739975, 'ok')
# AdaBoostClassifier robust scaling
# /home/jmayer/.local/share/virtualenvs/FutureReco2-AsCagFYD/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1859: UserWarning: y_pred contains classes not in y_true
#   warnings.warn('y_pred contains classes not in y_true')
# ('AdaBoostClassifier', 'robust scaling', 0.24878782578251554, 'fast', 462.9791250228882, 'ok')
# AdaBoostClassifier power transformation (Yeo-Johnson)
# ('AdaBoostClassifier', 'power transformation (Yeo-Johnson)', 0.2619868112466336, 'fast', 429.33453392982483, 'ok')
# AdaBoostClassifier quantile transformation (gaussian pdf)
# ('AdaBoostClassifier', 'quantile transformation (gaussian pdf)', 0.28005826374303855, 'fast', 466.0326180458069, 'ok')
# AdaBoostClassifier quantile transformation (uniform pdf)
# ('AdaBoostClassifier', 'quantile transformation (uniform pdf)', 0.2686092391975205, 'fast', 456.00977778434753, 'ok')
# AdaBoostClassifier sample-wise L2 normalizing
# ('AdaBoostClassifier', 'sample-wise L2 normalizing', 0.28515800281099757, 'fast', 465.5604405403137, 'ok')
# DecisionTreeClassifier Unscaled data
# ('DecisionTreeClassifier', 'Unscaled data', 0.43912872207068965, 'medi', 19.098145961761475, 'ok')
# DecisionTreeClassifier standard scaling
# ('DecisionTreeClassifier', 'standard scaling', 0.438788381051702, 'medi', 19.132768154144287, 'ok')
# DecisionTreeClassifier min-max scaling
# ('DecisionTreeClassifier', 'min-max scaling', 0.43844538206880546, 'medi', 18.18930196762085, 'ok')
# DecisionTreeClassifier max-abs scaling
# ('DecisionTreeClassifier', 'max-abs scaling', 0.43925536847719154, 'medi', 27.049118041992188, 'ok')
# DecisionTreeClassifier robust scaling
# ('DecisionTreeClassifier', 'robust scaling', 0.4319329841707071, 'medi', 31.72611689567566, 'ok')
# DecisionTreeClassifier power transformation (Yeo-Johnson)
# ('DecisionTreeClassifier', 'power transformation (Yeo-Johnson)', 0.43745764289856903, 'medi', 17.521433353424072, 'ok')
# DecisionTreeClassifier quantile transformation (gaussian pdf)
# ('DecisionTreeClassifier', 'quantile transformation (gaussian pdf)', 0.43583442949532136, 'medi', 19.330677270889282, 'ok')
# DecisionTreeClassifier quantile transformation (uniform pdf)
# ('DecisionTreeClassifier', 'quantile transformation (uniform pdf)', 0.4325438013896512, 'medi', 18.904245138168335, 'ok')
# DecisionTreeClassifier sample-wise L2 normalizing
# ('DecisionTreeClassifier', 'sample-wise L2 normalizing', 0.46960218992162933, 'medi', 17.006917715072632, 'ok')
# ExtraTreeClassifier Unscaled data
# ('ExtraTreeClassifier', 'Unscaled data', 0.45838475573401927, 'fast', 6.503219127655029, 'ok')
# ExtraTreeClassifier standard scaling
# ('ExtraTreeClassifier', 'standard scaling', 0.4652118600249899, 'fast', 6.576742172241211, 'ok')
# ExtraTreeClassifier min-max scaling
# ('ExtraTreeClassifier', 'min-max scaling', 0.46389502327545046, 'fast', 6.303517818450928, 'ok')
# ExtraTreeClassifier max-abs scaling
# ('ExtraTreeClassifier', 'max-abs scaling', 0.4628042090617846, 'fast', 6.85213041305542, 'ok')
# ExtraTreeClassifier robust scaling
# ('ExtraTreeClassifier', 'robust scaling', 0.4580087852291456, 'fast', 6.6054065227508545, 'ok')
# ExtraTreeClassifier power transformation (Yeo-Johnson)
# ('ExtraTreeClassifier', 'power transformation (Yeo-Johnson)', 0.4743202721518174, 'fast', 4.030405282974243, 'ok')
# ExtraTreeClassifier quantile transformation (gaussian pdf)
# ('ExtraTreeClassifier', 'quantile transformation (gaussian pdf)', 0.47650922953218977, 'fast', 4.050832271575928, 'ok')
# ExtraTreeClassifier quantile transformation (uniform pdf)
# ('ExtraTreeClassifier', 'quantile transformation (uniform pdf)', 0.477951899074097, 'fast', 3.9098191261291504, 'ok')
# ExtraTreeClassifier sample-wise L2 normalizing
# ('ExtraTreeClassifier', 'sample-wise L2 normalizing', 0.4147998758403552, 'fast', 6.770071744918823, 'ok')
# ExtraTreesClassifier Unscaled data
# ('ExtraTreesClassifier', 'Unscaled data', 0.5309613269257331, 'medi', 3.6467103958129883, 'ok')
# ExtraTreesClassifier standard scaling
# ('ExtraTreesClassifier', 'standard scaling', 0.5371337676626323, 'medi', 4.654314994812012, 'ok')
# ExtraTreesClassifier min-max scaling
# ('ExtraTreesClassifier', 'min-max scaling', 0.53754839618184, 'medi', 3.4650766849517822, 'ok')
# ExtraTreesClassifier max-abs scaling
# ('ExtraTreesClassifier', 'max-abs scaling', 0.542464634310985, 'medi', 3.616684675216675, 'ok')
# ExtraTreesClassifier robust scaling
# ('ExtraTreesClassifier', 'robust scaling', 0.5364428546566656, 'medi', 5.3984761238098145, 'ok')
# ExtraTreesClassifier power transformation (Yeo-Johnson)
# ('ExtraTreesClassifier', 'power transformation (Yeo-Johnson)', 0.539041249194502, 'medi', 27.550533533096313, 'ok')
# ExtraTreesClassifier quantile transformation (gaussian pdf)
# ('ExtraTreesClassifier', 'quantile transformation (gaussian pdf)', 0.545629769665938, 'medi', 2.5842225551605225, 'ok')
# ExtraTreesClassifier quantile transformation (uniform pdf)
# ('ExtraTreesClassifier', 'quantile transformation (uniform pdf)', 0.5369658123160623, 'medi', 2.6292455196380615, 'ok')
# ExtraTreesClassifier sample-wise L2 normalizing
# ('ExtraTreesClassifier', 'sample-wise L2 normalizing', 0.4980183049484018, 'medi', 4.112478494644165, 'ok')
# RandomForestClassifier Unscaled data
# ('RandomForestClassifier', 'Unscaled data', 0.5276261969185035, 'medi', 1.8736367225646973, 'ok')
# RandomForestClassifier standard scaling
# ('RandomForestClassifier', 'standard scaling', 0.5421822365494279, 'medi', 1.915001630783081, 'ok')
# RandomForestClassifier min-max scaling
# ('RandomForestClassifier', 'min-max scaling', 0.5361150937416986, 'medi', 1.791773796081543, 'ok')
# RandomForestClassifier max-abs scaling
# ('RandomForestClassifier', 'max-abs scaling', 0.5411831298919249, 'medi', 1.797511339187622, 'ok')
# RandomForestClassifier robust scaling
# ('RandomForestClassifier', 'robust scaling', 0.53300644524102, 'medi', 1.8336052894592285, 'ok')
# RandomForestClassifier power transformation (Yeo-Johnson)
# ('RandomForestClassifier', 'power transformation (Yeo-Johnson)', 0.5371149652562722, 'medi', 1.7849597930908203, 'ok')
# RandomForestClassifier quantile transformation (gaussian pdf)
# ('RandomForestClassifier', 'quantile transformation (gaussian pdf)', 0.5501848976799327, 'medi', 1.7681615352630615, 'ok')
# RandomForestClassifier quantile transformation (uniform pdf)
# ('RandomForestClassifier', 'quantile transformation (uniform pdf)', 0.5438716917497047, 'medi', 1.7818353176116943, 'ok')
# RandomForestClassifier sample-wise L2 normalizing
# ('RandomForestClassifier', 'sample-wise L2 normalizing', 0.5279004025161251, 'medi', 1.7749130725860596, 'ok')
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 77.2min finished

# %%
results_o = []
for mname, modelorg, speed in models_o:
    try:
        tmp = Parallel(n_jobs=10, verbose=1)(
            delayed(train_model_wrap)(mname, modelorg, speed, sname, data)
            for sname, data in x_scalers_split.items()
        )
        results_o.extend(tmp)
    except Exception as err:
        print(err)
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed:  8.4min finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed: 16.1min finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed:  1.9min finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed:   24.0s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed:   22.2s finished
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   9 out of   9 | elapsed:  3.7min finished

# %%
results = results_a1 + results_a2 + results_b + results_s + results_o
resultsdf = pd.DataFrame(results)
pd.options.display.max_rows = 999
resultsdf.columns = ["Model", "Scaler", "BAC", "Speed", "Time", "Status"]
resultsdf.sort_values(by=["BAC", "Time"], ascending=[False, True], inplace=True)
resultsdf.style.hide_index().format({"BAC": "{:.2%}", "Time": "{:.2f}"}).bar(
    subset=["BAC"], color="lightgreen"
).bar(subset=["Time"], color="lightblue")
# Out:
# <style  type="text/css" >
#     #T_c4b9730a_4820_11ea_a837_1866da8578c0row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.3%, transparent 0.3%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.3%, transparent 0.3%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.5%, transparent 0.5%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.0%, transparent 99.0%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.9%, transparent 98.9%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.4%, transparent 0.4%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.8%, transparent 98.8%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.5%, transparent 0.5%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.7%, transparent 0.7%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.6%, transparent 98.6%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.6%, transparent 0.6%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.4%, transparent 98.4%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.6%, transparent 0.6%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 89.4%, transparent 89.4%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 88.8%, transparent 88.8%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row11_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 87.1%, transparent 87.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row12_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 85.4%, transparent 85.4%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row13_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 84.7%, transparent 84.7%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row14_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.4%, transparent 0.4%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 84.3%, transparent 84.3%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row15_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.6%, transparent 83.6%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row16_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.3%, transparent 83.3%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row17_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.1%, transparent 0.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.1%, transparent 83.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row18_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.2%, transparent 0.2%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.1%, transparent 83.1%);
#         }    #T_c4b9730a_4820_11ea_a837_1866da8578c0row19_col4 {
#             width:  10em;
#              height:  80%;
#             background:
