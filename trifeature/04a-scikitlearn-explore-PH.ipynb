# %% [markdown]
# # Multiplicity determination with Scikit-learn classifiers

# %% [markdown]
# Here we test out scikit-learn classification models for multiplicity reconstruction with the three main features number of hits, number of clusters, and total deposited energy.

# %%
label = "nPH"
nmax = 4

# %%
import sys
import time

import numpy as np
import pandas as pd
import sklearn
from joblib import Parallel, delayed
from sklearn import *
from sklearn.experimental import enable_hist_gradient_boosting

sys.path.append("..")
from helpers import tridata, with_timeout

# %% [markdown]
# Load ALL the classification models from scikit-learn.
# Note that some models are very slow to train with large datasets or crash outright, so we give them a reduced number of (shuffled) rows to learn.
# Note that `n_jobs=1` is used, as parallelism is introduced later.

# %%
models = [
    ("AdaBoostClassifier", sklearn.ensemble.AdaBoostClassifier(), "fast"),
    ("BaggingClassifier", sklearn.ensemble.BaggingClassifier(n_jobs=1), "fast"),
    ("BernoulliNB", sklearn.naive_bayes.BernoulliNB(), "fast"),
    ("CalibratedClassifierCV", sklearn.calibration.CalibratedClassifierCV(cv=5), "slow"),
    ("ComplementNB", sklearn.naive_bayes.ComplementNB(), "fast"),
    ("DecisionTreeClassifier", sklearn.tree.DecisionTreeClassifier(), "fast"),
    ("ExtraTreeClassifier", sklearn.tree.ExtraTreeClassifier(), "fast"),
    ("ExtraTreesClassifier", sklearn.ensemble.ExtraTreesClassifier(n_estimators=100, n_jobs=1), "medi"),
    ("GaussianNB", sklearn.naive_bayes.GaussianNB(), "fast"),
    # crashes ('GaussianProcessClassifier', sklearn.gaussian_process.GaussianProcessClassifier(), 'slow'),
    ("GradientBoostingClassifier", sklearn.ensemble.GradientBoostingClassifier(), "slow"),
    ("HistGradientBoostingClassifier", sklearn.ensemble.HistGradientBoostingClassifier(), "slow"),
    ("KNeighborsClassifier", sklearn.neighbors.KNeighborsClassifier(n_jobs=1), "fast"),
    # ('LabelPropagation', sklearn.semi_supervised.LabelPropagation(), 'slow'),  # requires too much memory to train with larger datasets
    # ('LabelSpreading', sklearn.semi_supervised.LabelSpreading(), 'slow'),  # bit slow
    ("LinearDiscriminantAnalysis", sklearn.discriminant_analysis.LinearDiscriminantAnalysis(), "fast"),
    ("LinearSVC", sklearn.svm.LinearSVC(max_iter=20000), "slow"),  # slow with unscaled data
    (
        "LogisticRegression",
        sklearn.linear_model.LogisticRegression(solver="lbfgs", multi_class="auto", max_iter=20000),
        "slow",
    ),  # slow with unscaled data
    (
        "LogisticRegressionCV",
        sklearn.linear_model.LogisticRegressionCV(cv=5, solver="lbfgs", multi_class="auto", max_iter=20000),
        "slow",
    ),
    ("MLPClassifier", sklearn.neural_network.MLPClassifier(), "slow"),
    ("MultinomialNB", sklearn.naive_bayes.MultinomialNB(), "fast"),
    ("NearestCentroid", sklearn.neighbors.NearestCentroid(), "fast"),
    # nu infeasible ('NuSVC', sklearn.svm.NuSVC(), 'fast'),
    (
        "PassiveAggressiveClassifier",
        sklearn.linear_model.PassiveAggressiveClassifier(max_iter=1000, tol=1e-3, n_jobs=1),
        "fast",
    ),
    ("Perceptron", sklearn.linear_model.Perceptron(n_jobs=-1), "fast"),
    ("QuadraticDiscriminantAnalysis", sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis(), "fast"),
    (
        "RadiusNeighborsClassifier",
        sklearn.neighbors.RadiusNeighborsClassifier(radius=2, outlier_label=0, n_jobs=1),
        "fast",
    ),
    ("RandomForestClassifier", sklearn.ensemble.RandomForestClassifier(n_estimators=100, n_jobs=1), "medi"),
    ("RidgeClassifier", sklearn.linear_model.RidgeClassifier(), "fast"),
    ("RidgeClassifierCV", sklearn.linear_model.RidgeClassifierCV(), "fast"),
    ("SGDClassifier", sklearn.linear_model.SGDClassifier(max_iter=1000, tol=1e-3, n_jobs=1), "medi"),
    ("SVC", sklearn.svm.SVC(gamma="scale"), "slow"),
]

# %% [markdown]
# Some models only work with properly scaled data, so we prepare ALL available scalers.

# %%
scalers = [
    # ('Unscaled data', ),
    ("standard scaling", sklearn.preprocessing.StandardScaler()),
    ("min-max scaling", sklearn.preprocessing.MinMaxScaler()),
    ("max-abs scaling", sklearn.preprocessing.MaxAbsScaler()),
    ("robust scaling", sklearn.preprocessing.RobustScaler(quantile_range=(25, 75))),
    ("power transformation (Yeo-Johnson)", sklearn.preprocessing.PowerTransformer(method="yeo-johnson")),
    # ('power transformation (Box-Cox)', sklearn.preprocessing.PowerTransformer(method='box-cox')), # 'strictly zero' meh.
    ("quantile transformation (gaussian pdf)", sklearn.preprocessing.QuantileTransformer(output_distribution="normal")),
    ("quantile transformation (uniform pdf)", sklearn.preprocessing.QuantileTransformer(output_distribution="uniform")),
    ("sample-wise L2 normalizing", sklearn.preprocessing.Normalizer()),
]

# %% [markdown]
# Load train and test datasets

# %%
traindata, testdata = tridata(distance=15, doubleplane=30, energy=600, erel=500, nmax=nmax, physics="inclxx")

# %% [markdown]
# Train and Test data is passed through the scalers, including the "unscaled" scaler.

# %%
trainscaled = [("Unscaled data", traindata[["nHits", "nClus", "Edep"]], testdata[["nHits", "nClus", "Edep"]],)] + [
    (
        sname,
        scaler.fit_transform(traindata[["nHits", "nClus", "Edep"]]),
        scaler.transform(testdata[["nHits", "nClus", "Edep"]]),
    )
    for sname, scaler in scalers
]

# %% [markdown]
# Run all model/scaler combinations, in parallel. Note that we use timeouts per task, as setting at timeout in joblib will throw everything.

# %%
MEDIHEAD = 500000
SLOWHEAD = 200000


@with_timeout(1200 * 2)
def train_model(mname, modelorg, speed, sname, x_train, x_test):
    # These get killed without error?
    if mname == "RadiusNeighborsClassifier" and sname != "Unscaled data":
        return (mname, sname, np.NaN, speed, np.NaN, "Skipped")
    try:
        model = sklearn.base.clone(modelorg)
        start = time.time()
        if speed == "slow":
            model.fit(x_train[0:SLOWHEAD], traindata.head(SLOWHEAD)[[label]].values.ravel())
        elif speed == "medi":
            model.fit(x_train[0:MEDIHEAD], traindata.head(MEDIHEAD)[[label]].values.ravel())
        elif speed == "fast":
            model.fit(x_train, traindata[[label]].values.ravel())
        end = time.time()

        y_pred = model.predict(x_test)
        y_true = testdata[[label]].values.ravel()

        bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)
        return (mname, sname, bac, speed, (end - start), "ok")
    except Exception as err:
        return (mname, sname, np.NaN, speed, np.NaN, err)


def train_model_wrap(mname, modelorg, speed, sname, x_train, x_test):
    ret = train_model(mname, modelorg, speed, sname, x_train, x_test)
    if ret:
        return ret
    else:
        return (mname, sname, np.NaN, speed, np.NaN, "Timeout")

# %%
results = Parallel(n_jobs=4)(
    delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
    for sname, x_train, x_test in trainscaled
    for mname, modelorg, speed in models
)

# %%
resultsdf = pd.DataFrame(results)
pd.options.display.max_rows = 999
resultsdf.columns = ["Model", "Scaler", "BAC", "Speed", "Time", "Status"]
resultsdf.sort_values(by=["BAC", "Time", "Model"], ascending=[False, True, True], inplace=True)
resultsdf.style.hide_index().format({"BAC": "{:.2%}", "Time": "{:.2f}"}).bar(subset=["BAC"], color="lightgreen").bar(
    subset=["Time"], color="lightblue"
)
# Out:
# <style  type="text/css" >
# #T_2e90e992_12bb_11eb_bef9_74d435b9d955row0_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 25.3%, transparent 25.3%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 4.2%, transparent 4.2%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row2_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row3_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row4_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row5_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 4.9%, transparent 4.9%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 14.4%, transparent 14.4%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 4.6%, transparent 4.6%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row5_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row15_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row16_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row17_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 6.9%, transparent 6.9%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row6_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row20_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row63_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row152_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row153_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row154_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row167_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row208_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row213_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.7%, transparent 0.7%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row7_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row8_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row9_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row10_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row11_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row12_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row13_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row14_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row15_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row16_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row17_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row18_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.8%, transparent 99.8%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row7_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row59_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.5%, transparent 0.5%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row8_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row19_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row21_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row42_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row61_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row130_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row226_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.6%, transparent 0.6%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row9_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row10_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row168_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 0.8%, transparent 0.8%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row11_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row12_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row75_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 5.4%, transparent 5.4%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row13_col4,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row18_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 5.6%, transparent 5.6%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 6.6%, transparent 6.6%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row20_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row21_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row22_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row22_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 16.5%, transparent 16.5%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row23_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row24_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row23_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 31.0%, transparent 31.0%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row24_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 30.5%, transparent 30.5%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row25_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row26_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row27_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row28_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row29_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row30_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row31_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row32_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row33_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row34_col2,#T_2e90e992_12bb_11eb_bef9_74d435b9d955row35_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row25_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.8%, transparent 38.8%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row26_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.9%, transparent 38.9%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row27_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 38.2%, transparent 38.2%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row28_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 36.1%, transparent 36.1%);
#         }#T_2e90e992_12bb_11eb_bef9_74d435b9d955row29_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 21.5%, transparent 21.5%);
#         }#T_2e90e992_12bb_11eb_bef9_74d
