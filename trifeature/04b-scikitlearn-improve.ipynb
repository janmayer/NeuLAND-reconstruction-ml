# %% [markdown]
# # Try to improve LinearDiscriminantAnalysis
#
# TLDR: Settings don't matter. Use defaults.

# %% [markdown]
# ## Load Stuff

# %%
import numpy as np
import pandas as pd
import time
import sys
import joblib

import sklearn
from sklearn import *
from sklearn.experimental import enable_hist_gradient_boosting
import skopt

sys.path.append("..")
from helpers import filename_for
# Out:
# Welcome to JupyROOT 6.16/00

# %%
files = [filename_for(15, 30, 600, 500, n, "inclxx", s, "trifeature.pkl") for n in [1, 2, 3, 4] for s in range(20)]
dfs = [pd.read_pickle(file) for file in files]
data = pd.concat(dfs, ignore_index=True).sample(frac=1)
data = data[data["nHits"] > 0]
print(data.shape)
# Out:
# (789634, 6)

# %%
msk = np.random.rand(len(data)) < 0.8
traindata = data[msk]
testdata = data[~msk]

print(traindata.shape)
print(testdata.shape)
# Out:
# (631384, 6)
# (158250, 6)

# %%
features = ["nHits", "nClus", "Edep"]
label = ["nPN"]

# %% [markdown]
# ## Try to improve ...

# %%
def optimize_lda1():
    defaults = {
        "solver": "svd",
        "shrinkage": None,
        "priors": None,
        "n_components": None,
        "store_covariance": False,
        "tol": 0.0001,
    }

    model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(**defaults)

    opt = skopt.BayesSearchCV(
        model,
        {
            # "solver": skopt.space.Categorical(["svd", "lsqr", "eigen"]),
            # "shrinkage": skopt.space.Categorical(["auto", None]), # Works only with ‘lsqr’ and ‘eigen’ solvers.
            "n_components": skopt.space.Categorical([1, 2, 3]),
            "tol": skopt.space.Real(1e-3, 1e0, prior="log-uniform"),  # Only used if solver is ‘svd’.
        },
        n_iter=50,
        cv=2,
        n_jobs=2,
    )

    start = time.time()
    opt.fit(traindata[features], traindata[label].values.ravel())
    end = time.time()

    y_pred = opt.predict(testdata[features])
    y_true = testdata[label].values.ravel()
    bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    y_pred = opt.predict(data[features])
    y_true = data[label].values.ravel()
    bacall = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    return opt, ("LinearDiscriminantAnalysis", end - start, bac, bacall)

# %%
# %%capture
lda1_opt, lda1_result = optimize_lda1()

# %%
print(lda1_result)
print(lda1_opt.best_params_)
display(pd.DataFrame(lda1_opt.cv_results_))
# Out:
# ('LinearDiscriminantAnalysis', 78.09813165664673, 0.7119446530820162, 0.7106872878412864)
# OrderedDict([('n_components', 2), ('tol', 0.05904546236639551)])
#     split0_test_score  split1_test_score  mean_test_score  std_test_score  \
# 0            0.708060           0.707050         0.707555        0.000505
# 1            0.668889           0.668753         0.668821        0.000068
# 2            0.708060           0.707050         0.707555        0.000505
# 3            0.708060           0.707050         0.707555        0.000505
# 4            0.708060           0.707050         0.707555        0.000505
# 5            0.707747           0.706717         0.707232        0.000515
# 6            0.660824           0.661037         0.660931        0.000106
# 7            0.708060           0.707050         0.707555        0.000505
# 44        0.000423                   2   0.001501
# 45        0.000302                   2   0.019391
# 46        0.003416                   2   0.101381
# 47        0.005531                   3   0.094188
# 48        0.000112                   3   0.067869
# 49        0.000816                   1   0.185618
#
#                                                params
# 0     {'n_components': 2, 'tol': 0.05904546236639551}
# 1      {'n_components': 2, 'tol': 0.5065388066280351}
# 2    {'n_components': 2, 'tol': 0.011990885416125256}
# 3    {'n_components': 3, 'tol': 0.011595490128654762}
# 4    {'n_components': 2, 'tol': 0.030236576981032715}
# 5   {'n_components': 2, 'tol': 0.0024966122752312202}
# 6      {'n_components': 2, 'tol': 0.9456128454430527}
# 7     {'n_components': 2, 'tol': 0.09674129546631158}
# 8     {'n_components': 2, 'tol': 0.01061712091348387}
# 9     {'n_components': 2, 'tol': 0.04531010743225246}
# 10                  {'n_components': 1, 'tol': 0.001}
# 11                  {'n_components': 3, 'tol': 0.001}
# 12   {'n_components': 1, 'tol': 0.030840976305591808}
# 13  {'n_components': 1, 'tol': 0.0035515457143213635}
# 14  {'n_components': 2, 'tol': 0.0010013330178543335}
# 15    {'n_components': 3, 'tol': 0.03721075458976884}
# 16   {'n_components': 3, 'tol': 0.003042806780459381}
# 17   {'n_components': 1, 'tol': 0.026667882859407622}
# 18  {'n_components': 2, 'tol': 0.0010017629478730028}
# 19   {'n_components': 1, 'tol': 0.005605609625184553}
# 20   {'n_components': 3, 'tol': 0.028499815173581626}
# 21  {'n_components': 1, 'tol': 0.0010051262223117396}
# 22    {'n_components': 1, 'tol': 0.07343676918982334}
# 23  {'n_components': 3, 'tol': 0.0022596115446662153}
# 24      {'n_components': 3, 'tol': 0.073994484487876}
# 25   {'n_components': 3, 'tol': 0.001000128410198439}
# 26  {'n_components': 2, 'tol': 0.0024057567784606746}
# 27                    {'n_components': 3, 'tol': 1.0}
# 28   {'n_components': 2, 'tol': 0.005212545811981154}
# 29   {'n_components': 3, 'tol': 0.005914326408190133}
# 30      {'n_components': 3, 'tol': 0.051626268798566}
# 31  {'n_components': 1, 'tol': 0.0015883924756625197}
# 32  {'n_components': 3, 'tol': 0.0015557894038334679}
# 33    {'n_components': 1, 'tol': 0.05141604610253841}
# 34     {'n_components': 1, 'tol': 0.1419005938908288}
# 35   {'n_components': 1, 'tol': 0.015960382442139046}
# 36   {'n_components': 3, 'tol': 0.017101801056648266}
# 37    {'n_components': 3, 'tol': 0.05031535202391802}
# 38    {'n_components': 1, 'tol': 0.09441112984736003}
# 39   {'n_components': 3, 'tol': 0.007776661051758453}
# 40    {'n_components': 2, 'tol': 0.15131656547118696}
# 41   {'n_components': 1, 'tol': 0.008367627897693604}
# 42     {'n_components': 3, 'tol': 0.0502170566694451}
# 43   {'n_components': 3, 'tol': 0.004222087580069829}
# 44   {'n_components': 2, 'tol': 0.001500617578911127}
# 45   {'n_components': 2, 'tol': 0.019390863289905982}
# 46    {'n_components': 2, 'tol': 0.10138060819254877}
# 47    {'n_components': 3, 'tol': 0.09418808650941803}
# 48    {'n_components': 3, 'tol': 0.06786933178452992}
# 49    {'n_components': 1, 'tol': 0.18561756890858602}

# %%
def optimize_lda2():
    defaults = {
        "solver": "svd",
        "shrinkage": None,
        "priors": None,
        "n_components": None,
        "store_covariance": False,
        "tol": 0.0001,
    }

    model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(**defaults)

    opt = skopt.BayesSearchCV(
        model,
        {
            "solver": skopt.space.Categorical(["lsqr", "eigen"]),
            # "shrinkage": skopt.space.Categorical(["auto"]),#, None]),  # Works only with ‘lsqr’ and ‘eigen’ solvers.
            "n_components": skopt.space.Categorical([1, 2, 3]),
            # "tol": skopt.space.Real(1e-3, 1e0, prior="log-uniform"), # Only used if solver is ‘svd’.
        },
        n_iter=50,
        cv=2,
        n_jobs=2,
    )

    start = time.time()
    opt.fit(traindata[features], traindata[label].values.ravel())
    end = time.time()

    y_pred = opt.predict(testdata[features])
    y_true = testdata[label].values.ravel()
    bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    y_pred = opt.predict(data[features])
    y_true = data[label].values.ravel()
    bacall = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    return opt, ("LinearDiscriminantAnalysis", end - start, bac, bacall)

# %%
# %%capture
lda2_opt, lda2_result = optimize_lda2()

# %%
print(lda2_result)
print(lda2_opt.best_params_)
display(pd.DataFrame(lda2_opt.cv_results_))
# Out:
# ('LinearDiscriminantAnalysis', 63.20529079437256, 0.7116389101523001, 0.7103993936585928)
# OrderedDict([('n_components', 1), ('solver', 'eigen')])
#     split0_test_score  split1_test_score  mean_test_score  std_test_score  \
# 0            0.707712           0.706762         0.707237        0.000475
# 1            0.707712           0.706762         0.707237        0.000475
# 2            0.707712           0.706762         0.707237        0.000475
# 3            0.707712           0.706762         0.707237        0.000475
# 4            0.707712           0.706762         0.707237        0.000475
# 5            0.707712           0.706762         0.707237        0.000475
# 6            0.707712           0.706762         0.707237        0.000475
# 7            0.707712           0.706762         0.707237        0.000475
# 8            0.707712           0.706762         0.707237        0.000475
# 9            0.707712           0.706762         0.707237        0.000475
# 10           0.707712           0.706762         0.707237        0.000475
# 11           0.707712           0.706762         0.707237        0.000475
# 12           0.707712           0.706762         0.707237        0.000475
# 13           0.707712           0.706762         0.707237        0.000475
# 14           0.707712           0.706762         0.707237        0.000475
# 15           0.707712           0.706762         0.707237        0.000475
# 16           0.707712           0.706762         0.707237        0.000475
# 17           0.707712           0.706762         0.707237        0.000475
# 18           0.707712           0.706762         0.707237        0.000475
# 19           0.707712           0.706762         0.707237        0.000475
# 20           0.707712           0.706762         0.707237        0.000475
# 21           0.707712           0.706762         0.707237        0.000475
# 22           0.707712           0.706762         0.707237        0.000475
# 23           0.707712           0.706762         0.707237        0.000475
# 36                1       0.160167      0.001224         0.037289
# 37                1       0.173661      0.001903         0.037436
# 38                1       0.172397      0.001830         0.037404
# 39                1       0.160926      0.001577         0.036840
# 40                1       0.158219      0.000919         0.040821
# 41                1       0.173812      0.000933         0.041922
# 42                1       0.171326      0.001733         0.057004
# 43                1       0.160079      0.001748         0.041528
# 44                1       0.171222      0.002978         0.040463
# 45                1       0.160445      0.001670         0.040643
# 46                1       0.160126      0.001984         0.041361
# 47                1       0.175997      0.003562         0.039915
# 48                1       0.161070      0.001715         0.040633
# 49                1       0.184394      0.002853         0.040811
#
#     std_score_time  param_n_components param_solver  \
# 0     3.991127e-04                   1        eigen
# 1     2.250671e-04                   1         lsqr
# 2     1.670122e-04                   3         lsqr
# 3     4.194975e-04                   2        eigen
# 4     4.086494e-04                   1        eigen
# 5     3.553629e-04                   2        eigen
# 6     4.994869e-05                   1        eigen
# 7     3.655553e-03                   1         lsqr
# 8     7.096529e-04                   2         lsqr
# 9     7.129908e-04                   3         lsqr
# 10    1.178384e-03                   3        eigen
# 11    6.085634e-04                   2         lsqr
# 12    1.620293e-03                   3        eigen
# 13    5.568266e-04                   2         lsqr
# 14    1.242518e-03                   3        eigen
# 15    5.609989e-04                   1         lsqr
# 16    1.262307e-03                   2        eigen
# 17    5.043745e-04                   3         lsqr
# 18    1.290917e-03                   2        eigen
# 19    4.492998e-04                   3         lsqr
# 20    7.284880e-04                   1         lsqr
# 21    3.441572e-04                   3        eigen
# 22    8.194447e-04                   2         lsqr
# 23    1.203299e-03                   1        eigen
# 24    1.175046e-03                   1        eigen
# 25    5.832911e-04                   2         lsqr
# 26    5.775690e-04                   3         lsqr
# 27    7.177591e-04                   2        eigen
# 28    6.465912e-04                   3        eigen
# 29    6.279945e-04                   1         lsqr
# 30    1.080751e-03                   3         lsqr
# 31    7.394552e-04                   2        eigen
# 32    6.339550e-04                   1         lsqr
# 33    4.309058e-03                   3        eigen
# 34    4.344225e-03                   2         lsqr
# 35    3.010035e-04                   1        eigen
# 36    4.933000e-03                   1         lsqr
# 37    4.221916e-03                   3        eigen
# 38    4.234314e-03                   2        eigen
# 39    4.252791e-03                   2         lsqr
# 40    1.207590e-04                   3         lsqr
# 41    8.344650e-07                   1        eigen
# 42    5.040407e-03                   3        eigen
# 43    4.732609e-05                   2         lsqr
# 44    1.213789e-03                   1        eigen
# 45    6.175041e-04                   3         lsqr
# 46    1.499534e-03                   1         lsqr
# 47    9.574890e-04                   2        eigen
# 48    5.120039e-04                   1         lsqr
# 49    1.639366e-03                   3        eigen
#
#                                     params
# 0   {'n_components': 1, 'solver': 'eigen'}
# 1    {'n_components': 1, 'solver': 'lsqr'}
# 2    {'n_components': 3, 'solver': 'lsqr'}
# 3   {'n_components': 2, 'solver': 'eigen'}
# 4   {'n_components': 1, 'solver': 'eigen'}
# 5   {'n_components': 2, 'solver': 'eigen'}
# 6   {'n_components': 1, 'solver': 'eigen'}
# 7    {'n_components': 1, 'solver': 'lsqr'}
# 8    {'n_components': 2, 'solver': 'lsqr'}
# 9    {'n_components': 3, 'solver': 'lsqr'}
# 10  {'n_components': 3, 'solver': 'eigen'}
# 11   {'n_components': 2, 'solver': 'lsqr'}
# 12  {'n_components': 3, 'solver': 'eigen'}
# 13   {'n_components': 2, 'solver': 'lsqr'}
# 14  {'n_components': 3, 'solver': 'eigen'}
# 15   {'n_components': 1, 'solver': 'lsqr'}
# 16  {'n_components': 2, 'solver': 'eigen'}
# 17   {'n_components': 3, 'solver': 'lsqr'}
# 18  {'n_components': 2, 'solver': 'eigen'}
# 19   {'n_components': 3, 'solver': 'lsqr'}
# 20   {'n_components': 1, 'solver': 'lsqr'}
# 21  {'n_components': 3, 'solver': 'eigen'}
# 22   {'n_components': 2, 'solver': 'lsqr'}
# 23  {'n_components': 1, 'solver': 'eigen'}
# 24  {'n_components': 1, 'solver': 'eigen'}
# 25   {'n_components': 2, 'solver': 'lsqr'}
# 26   {'n_components': 3, 'solver': 'lsqr'}
# 27  {'n_components': 2, 'solver': 'eigen'}
# 28  {'n_components': 3, 'solver': 'eigen'}
# 29   {'n_components': 1, 'solver': 'lsqr'}
# 30   {'n_components': 3, 'solver': 'lsqr'}
# 31  {'n_components': 2, 'solver': 'eigen'}
# 32   {'n_components': 1, 'solver': 'lsqr'}
# 33  {'n_components': 3, 'solver': 'eigen'}
# 34   {'n_components': 2, 'solver': 'lsqr'}
# 35  {'n_components': 1, 'solver': 'eigen'}
# 36   {'n_components': 1, 'solver': 'lsqr'}
# 37  {'n_components': 3, 'solver': 'eigen'}
# 38  {'n_components': 2, 'solver': 'eigen'}
# 39   {'n_components': 2, 'solver': 'lsqr'}
# 40   {'n_components': 3, 'solver': 'lsqr'}
# 41  {'n_components': 1, 'solver': 'eigen'}
# 42  {'n_components': 3, 'solver': 'eigen'}
# 43   {'n_components': 2, 'solver': 'lsqr'}
# 44  {'n_components': 1, 'solver': 'eigen'}
# 45   {'n_components': 3, 'solver': 'lsqr'}
# 46   {'n_components': 1, 'solver': 'lsqr'}
# 47  {'n_components': 2, 'solver': 'eigen'}
# 48   {'n_components': 1, 'solver': 'lsqr'}
# 49  {'n_components': 3, 'solver': 'eigen'}

# %% [markdown]
# ## Just train model with defaults settings and save

# %%
model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis()
model.fit(traindata[features], traindata[label].values.ravel())
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
y_pred = model.predict(testdata[features])
print(sklearn.metrics.balanced_accuracy_score(testdata[label], y_pred))
# Out:
# 0.7116389101523001

# %%
joblib.dump(model, "models/mult_30dp_600AMeV_4n_LinearDiscriminantAnalysis.pkl")
# Out:
# ['models/mult_30dp_600AMeV_4n_LinearDiscriminantAnalysis.pkl']
