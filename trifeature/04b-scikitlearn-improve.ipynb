# %% [markdown]
# # Try to improve LinearDiscriminantAnalysis
#
# TLDR: Settings don't matter. Use defaults.

# %% [markdown]
# ## Load Stuff

# %%
import numpy as np
import pandas as pd
import time
import sys
import joblib

import sklearn
from sklearn import *
from sklearn.experimental import enable_hist_gradient_boosting
import skopt

sys.path.append("..")
from helpers import filename_for
from plotconf import *
# Out:
# Welcome to JupyROOT 6.16/00

# %%
files = [filename_for(15, 30, 600, 500, n, "inclxx", s, "trifeature.pkl") for n in [1, 2, 3, 4] for s in range(20)]
dfs = [pd.read_pickle(file) for file in files]
data = pd.concat(dfs, ignore_index=True).sample(frac=1)
data = data[data["nHits"] > 0]
print(data.shape)
# Out:
# (789634, 6)

# %%
msk = np.random.rand(len(data)) < 0.8
traindata = data[msk]
testdata = data[~msk]

print(traindata.shape)
print(testdata.shape)
# Out:
# (631401, 6)
# (158233, 6)

# %%
features = ["nHits", "nClus", "Edep"]
label = ["nPN"]

# %% [markdown]
# ## Try to improve ...

# %%
def optimize_lda1():
    defaults = {
        "solver": "svd",
        "shrinkage": None,
        "priors": None,
        "n_components": None,
        "store_covariance": False,
        "tol": 0.0001,
    }

    model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(**defaults)

    opt = skopt.BayesSearchCV(
        model,
        {
            # "solver": skopt.space.Categorical(["svd", "lsqr", "eigen"]),
            # "shrinkage": skopt.space.Categorical(["auto", None]), # Works only with ‘lsqr’ and ‘eigen’ solvers.
            "n_components": skopt.space.Categorical([1, 2, 3]),
            "tol": skopt.space.Real(1e-3, 1e0, prior="log-uniform"),  # Only used if solver is ‘svd’.
        },
        n_iter=50,
        cv=2,
        n_jobs=2,
    )

    start = time.time()
    opt.fit(traindata[features], traindata[label].values.ravel())
    end = time.time()

    y_pred = opt.predict(testdata[features])
    y_true = testdata[label].values.ravel()
    bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    y_pred = opt.predict(data[features])
    y_true = data[label].values.ravel()
    bacall = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    return opt, ("LinearDiscriminantAnalysis", end - start, bac, bacall)

# %%
# %%capture
lda1_opt, lda1_result = optimize_lda1()

# %%
print(lda1_result)
print(lda1_opt.best_params_)
display(pd.DataFrame(lda1_opt.cv_results_))
# Out:
# ('LinearDiscriminantAnalysis', 91.94827389717102, 0.7110080400520146, 0.7106556727454868)
# OrderedDict([('n_components', 1), ('tol', 0.013203039688571725)])
#     split0_test_score  split1_test_score  mean_test_score  std_test_score  \
# 0            0.707454           0.707285         0.707370        0.000084
# 1            0.707454           0.707285         0.707370        0.000084
# 2            0.707454           0.707285         0.707370        0.000084
# 3            0.707638           0.707612         0.707625        0.000013
# 4            0.707638           0.707612         0.707625        0.000013
# 5            0.707454           0.707285         0.707370        0.000084
# 6            0.707638           0.707612         0.707625        0.000013
# 7            0.707638           0.707612         0.707625        0.000013
# 8            0.668794           0.668882         0.668838        0.000044
# 9            0.707454           0.707285         0.707370        0.000084
# 10           0.707454           0.707285         0.707370        0.000084
# 11           0.253468           0.253472         0.253470        0.000002
# 12           0.707638           0.707612         0.707625        0.000013
# 13           0.707454           0.707285         0.707370        0.000084
# 14           0.707638           0.707612         0.707625        0.000013
# 35                1       0.192690      0.000829         0.042133
# 36               22       0.192026      0.000745         0.042502
# 37                1       0.193300      0.005474         0.041704
# 38               22       0.191985      0.000846         0.041839
# 39                1       0.181168      0.000537         0.041192
# 40               22       0.183763      0.000092         0.037436
# 41               22       0.183825      0.002684         0.041498
# 42                1       0.183620      0.002023         0.037230
# 43                1       0.183579      0.002513         0.041253
# 44               22       0.181969      0.000239         0.042192
# 45               22       0.183285      0.002358         0.041810
# 46                1       0.190593      0.000084         0.048242
# 47                1       0.180543      0.002286         0.041871
# 48               22       0.182430      0.001857         0.042132
# 49                1       0.181840      0.002226         0.041175
#
#     std_score_time  param_n_components  param_tol  \
# 0         0.003066                   2   0.001283
# 1         0.000239                   2   0.003098
# 2         0.000335                   1   0.001678
# 3         0.000081                   1   0.013203
# 4         0.000124                   2   0.061922
# 5         0.000270                   3   0.001642
# 6         0.000941                   3   0.033053
# 7         0.000413                   2   0.290972
# 8         0.000104                   1   0.895909
# 9         0.001153                   2   0.007085
# 10        0.001222                   1   0.001000
# 11        0.000185                   3   1.000000
# 12        0.006651                   3   0.016397
# 13        0.003841                   3   0.001000
# 14        0.000107                   1   0.147276
# 15        0.000229                   2   0.008276
# 16        0.003857                   2   0.008155
# 17        0.000294                   2   0.008589
# 18        0.000099                   2   0.008710
# 19        0.001045                   2   0.006485
# 20        0.003993                   2   0.006409
# 21        0.003831                   2   0.006454
# 22        0.007068                   3   0.004846
# 23        0.000046                   2   0.026306
# 24        0.000015                   2   0.145747
# 25        0.000168                   2   0.010107
# 26        0.000096                   3   0.020335
# 27        0.000180                   3   0.002609
# 28        0.000135                   1   0.040953
# 29        0.000035                   2   0.001000
# 30        0.000154                   3   0.009032
# 31        0.000056                   1   0.251337
# 32        0.000005                   1   0.003864
# 33        0.000157                   2   0.009898
# 34        0.004726                   3   0.001000
# 35        0.000391                   1   0.087866
# 36        0.000343                   3   0.006684
# 37        0.000072                   1   0.020966
# 38        0.000542                   3   0.006699
# 39        0.000118                   2   0.175382
# 40        0.004601                   3   0.006790
# 41        0.000071                   3   0.006800
# 42        0.004749                   3   0.020961
# 43        0.000217                   3   0.045669
# 44        0.000268                   2   0.002036
# 45        0.000244                   1   0.001000
# 46        0.001409                   3   0.030207
# 47        0.000119                   2   0.037320
# 48        0.000172                   3   0.002930
# 49        0.000146                   3   0.064322
#
#                                                params
# 0    {'n_components': 2, 'tol': 0.001283024879055837}
# 1    {'n_components': 2, 'tol': 0.003097510030759836}
# 2    {'n_components': 1, 'tol': 0.001677704287873831}
# 3    {'n_components': 1, 'tol': 0.013203039688571725}
# 4     {'n_components': 2, 'tol': 0.06192219583955215}
# 5    {'n_components': 3, 'tol': 0.001641704571408362}
# 6     {'n_components': 3, 'tol': 0.03305299286226989}
# 7     {'n_components': 2, 'tol': 0.29097234189168114}
# 8      {'n_components': 1, 'tol': 0.8959087256706173}
# 9    {'n_components': 2, 'tol': 0.007085471823383633}
# 10                  {'n_components': 1, 'tol': 0.001}
# 11                    {'n_components': 3, 'tol': 1.0}
# 12   {'n_components': 3, 'tol': 0.016396907163668387}
# 13                  {'n_components': 3, 'tol': 0.001}
# 14    {'n_components': 1, 'tol': 0.14727644012165064}
# 15   {'n_components': 2, 'tol': 0.008276214112820372}
# 16    {'n_components': 2, 'tol': 0.00815450270650593}
# 17   {'n_components': 2, 'tol': 0.008589109594226674}
# 18   {'n_components': 2, 'tol': 0.008709642148854176}
# 19   {'n_components': 2, 'tol': 0.006484954374575366}
# 20   {'n_components': 2, 'tol': 0.006408783727962133}
# 21   {'n_components': 2, 'tol': 0.006453976545786326}
# 22   {'n_components': 3, 'tol': 0.004845991019102863}
# 23    {'n_components': 2, 'tol': 0.02630568505273342}
# 24    {'n_components': 2, 'tol': 0.14574743680324775}
# 25   {'n_components': 2, 'tol': 0.010107390308426344}
# 26   {'n_components': 3, 'tol': 0.020335253694748995}
# 27  {'n_components': 3, 'tol': 0.0026092230546147332}
# 28    {'n_components': 1, 'tol': 0.04095306583412043}
# 29                  {'n_components': 2, 'tol': 0.001}
# 30   {'n_components': 3, 'tol': 0.009031766389176488}
# 31    {'n_components': 1, 'tol': 0.25133724722637807}
# 32    {'n_components': 1, 'tol': 0.00386370722080513}
# 33   {'n_components': 2, 'tol': 0.009897665329477418}
# 34                  {'n_components': 3, 'tol': 0.001}
# 35    {'n_components': 1, 'tol': 0.08786583050057159}
# 36  {'n_components': 3, 'tol': 0.0066842924136315965}
# 37   {'n_components': 1, 'tol': 0.020965786417144607}
# 38   {'n_components': 3, 'tol': 0.006698606479814124}
# 39    {'n_components': 2, 'tol': 0.17538190348494043}
# 40   {'n_components': 3, 'tol': 0.006789955404154481}
# 41   {'n_components': 3, 'tol': 0.006800326187563706}
# 42    {'n_components': 3, 'tol': 0.02096135834837689}
# 43   {'n_components': 3, 'tol': 0.045669031315731363}
# 44  {'n_components': 2, 'tol': 0.0020360540433786755}
# 45                  {'n_components': 1, 'tol': 0.001}
# 46   {'n_components': 3, 'tol': 0.030206524191080525}
# 47    {'n_components': 2, 'tol': 0.03731956548321145}
# 48  {'n_components': 3, 'tol': 0.0029302673381194403}
# 49     {'n_components': 3, 'tol': 0.0643221956727688}

# %%
def optimize_lda2():
    defaults = {
        "solver": "svd",
        "shrinkage": None,
        "priors": None,
        "n_components": None,
        "store_covariance": False,
        "tol": 0.0001,
    }

    model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(**defaults)

    opt = skopt.BayesSearchCV(
        model,
        {
            "solver": skopt.space.Categorical(["lsqr", "eigen"]),
            # "shrinkage": skopt.space.Categorical(["auto"]),#, None]),  # Works only with ‘lsqr’ and ‘eigen’ solvers.
            "n_components": skopt.space.Categorical([1, 2, 3]),
            # "tol": skopt.space.Real(1e-3, 1e0, prior="log-uniform"), # Only used if solver is ‘svd’.
        },
        n_iter=50,
        cv=2,
        n_jobs=2,
    )

    start = time.time()
    opt.fit(traindata[features], traindata[label].values.ravel())
    end = time.time()

    y_pred = opt.predict(testdata[features])
    y_true = testdata[label].values.ravel()
    bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    y_pred = opt.predict(data[features])
    y_true = data[label].values.ravel()
    bacall = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)

    return opt, ("LinearDiscriminantAnalysis", end - start, bac, bacall)

# %%
# %%capture
lda2_opt, lda2_result = optimize_lda2()

# %%
print(lda2_result)
print(lda2_opt.best_params_)
# 12                1       0.174458      0.002439         0.047914
# 13                1       0.173414      0.001980         0.042815
# 14                1       0.163399      0.002491         0.046906
# 15                1       0.172103      0.001724         0.042350
# 16                1       0.162986      0.003985         0.041307
# 17                1       0.175302      0.002031         0.042732
# 18                1       0.161639      0.002694         0.042964
# 19                1       0.180758      0.002072         0.047801
# 20                1       0.174819      0.001432         0.048373
# 21                1       0.163644      0.002969         0.041189
# 22                1       0.175930      0.002576         0.042106
# 23                1       0.163862      0.003746         0.041067
# 24                1       0.174058      0.004792         0.041883
# 25                1       0.164140      0.005405         0.040837
# 26                1       0.162317      0.002903         0.046811
# 27                1       0.175386      0.000397         0.042121
# 28                1       0.173856      0.000128         0.042114
# 29                1       0.162785      0.000196         0.040912
# 30                1       0.160540      0.000087         0.040988
# 31                1       0.174976      0.000141         0.042131
# 32                1       0.160733      0.000089         0.036716
# 33                1       0.183639      0.000512         0.038337
# 34                1       0.159822      0.000211         0.037078
# 35                1       0.176546      0.001060         0.049432
# 36                1       0.159854      0.002162         0.036606
# 37                1       0.175847      0.001637         0.037384
# 38                1       0.175166      0.000004         0.038259
# 39                1       0.160828      0.000418         0.040789
# 40                1       0.171991      0.000509         0.042633
# 41                1       0.162222      0.000111         0.040930
# 42                1       0.174027      0.000396         0.042403
# 43                1       0.161029      0.000228         0.040738
# 44                1       0.161380      0.001922         0.041788
# 45                1       0.176907      0.003272         0.042561
# 46                1       0.161299      0.002903         0.046799
# 47                1       0.177785      0.002896         0.042766
# 48                1       0.161898      0.001991         0.041325
# 49                1       0.175427      0.002303         0.046758
#
#     std_score_time  param_n_components param_solver  \
# 0         0.000518                   3         lsqr
# 1         0.000491                   3         lsqr
# 2         0.000668                   1         lsqr
# 3         0.000114                   2        eigen
# 4         0.000989                   3         lsqr
# 5         0.000728                   3        eigen
# 6         0.001342                   2         lsqr
# 7         0.001052                   1        eigen
# 8         0.000741                   3         lsqr
# 9         0.000519                   1         lsqr
# 10        0.001210                   2        eigen
# 11        0.001076                   1        eigen
# 12        0.004628                   2        eigen
# 13        0.001275                   1        eigen
# 14        0.005304                   2         lsqr
# 15        0.000573                   3        eigen
# 16        0.000618                   1         lsqr
# 17        0.000945                   2        eigen
# 18        0.000963                   2         lsqr
# 19        0.004790                   3        eigen
# 20        0.006373                   1        eigen
# 21        0.000310                   2         lsqr
# 22        0.001057                   3        eigen
# 23        0.000198                   1         lsqr
# 24        0.000974                   3        eigen
# 25        0.000189                   1         lsqr
# 26        0.005157                   2         lsqr
# 27        0.000439                   1        eigen
# 28        0.000515                   2        eigen
# 29        0.000048                   3         lsqr
# 30        0.000201                   3         lsqr
# 31        0.000400                   2        eigen
# 32        0.004513                   1         lsqr
# 33        0.003963                   1        eigen
# 34        0.004291                   2         lsqr
# 35        0.015027                   3        eigen
# 36        0.004919                   1         lsqr
# 37        0.004560                   3        eigen
# 38        0.004154                   2        eigen
# 39        0.000257                   2         lsqr
# 40        0.000581                   1        eigen
# 41        0.000062                   3         lsqr
# 42        0.000301                   2        eigen
# 43        0.000211                   3         lsqr
# 44        0.000386                   1         lsqr
# 45        0.001346                   1        eigen
# 46        0.006055                   2         lsqr
# 47        0.000913                   3        eigen
# 48        0.000738                   2         lsqr
# 49        0.005559                   1        eigen
#
#                                     params
# 0    {'n_components': 3, 'solver': 'lsqr'}
# 1    {'n_components': 3, 'solver': 'lsqr'}
# 2    {'n_components': 1, 'solver': 'lsqr'}
# 3   {'n_components': 2, 'solver': 'eigen'}
# 4    {'n_components': 3, 'solver': 'lsqr'}
# 5   {'n_components': 3, 'solver': 'eigen'}
# 6    {'n_components': 2, 'solver': 'lsqr'}
# 7   {'n_components': 1, 'solver': 'eigen'}
# 8    {'n_components': 3, 'solver': 'lsqr'}
# 9    {'n_components': 1, 'solver': 'lsqr'}
# 10  {'n_components': 2, 'solver': 'eigen'}
# 11  {'n_components': 1, 'solver': 'eigen'}
# 12  {'n_components': 2, 'solver': 'eigen'}
# 13  {'n_components': 1, 'solver': 'eigen'}
# 14   {'n_components': 2, 'solver': 'lsqr'}
# 15  {'n_components': 3, 'solver': 'eigen'}
# 16   {'n_components': 1, 'solver': 'lsqr'}
# 17  {'n_components': 2, 'solver': 'eigen'}
# 18   {'n_components': 2, 'solver': 'lsqr'}
# 19  {'n_components': 3, 'solver': 'eigen'}
# 20  {'n_components': 1, 'solver': 'eigen'}
# 21   {'n_components': 2, 'solver': 'lsqr'}
# 22  {'n_components': 3, 'solver': 'eigen'}
# 23   {'n_components': 1, 'solver': 'lsqr'}
# 24  {'n_components': 3, 'solver': 'eigen'}
# 25   {'n_components': 1, 'solver': 'lsqr'}
# 26   {'n_components': 2, 'solver': 'lsqr'}
# 27  {'n_components': 1, 'solver': 'eigen'}
# 28  {'n_components': 2, 'solver': 'eigen'}
# 29   {'n_components': 3, 'solver': 'lsqr'}
# 30   {'n_components': 3, 'solver': 'lsqr'}
# 31  {'n_components': 2, 'solver': 'eigen'}
# 32   {'n_components': 1, 'solver': 'lsqr'}
# 33  {'n_components': 1, 'solver': 'eigen'}
# 34   {'n_components': 2, 'solver': 'lsqr'}
# 35  {'n_components': 3, 'solver': 'eigen'}
# 36   {'n_components': 1, 'solver': 'lsqr'}
# 37  {'n_components': 3, 'solver': 'eigen'}
# 38  {'n_components': 2, 'solver': 'eigen'}
# 39   {'n_components': 2, 'solver': 'lsqr'}
# 40  {'n_components': 1, 'solver': 'eigen'}
# 41   {'n_components': 3, 'solver': 'lsqr'}
# 42  {'n_components': 2, 'solver': 'eigen'}
# 43   {'n_components': 3, 'solver': 'lsqr'}
# 44   {'n_components': 1, 'solver': 'lsqr'}
# 45  {'n_components': 1, 'solver': 'eigen'}
# 46   {'n_components': 2, 'solver': 'lsqr'}
# 47  {'n_components': 3, 'solver': 'eigen'}
# 48   {'n_components': 2, 'solver': 'lsqr'}
# 49  {'n_components': 1, 'solver': 'eigen'}

# %% [markdown]
# ## Just train model with defaults settings and save

# %%
model = sklearn.discriminant_analysis.LinearDiscriminantAnalysis()
model.fit(traindata[features], traindata[label].values.ravel())
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
y_pred = model.predict(testdata[features])
print(sklearn.metrics.balanced_accuracy_score(testdata[label], y_pred))
# Out:
# 0.7105857028964911

# %%
joblib.dump(model, "models/mult_30dp_600AMeV_4n_LinearDiscriminantAnalysis.pkl")
# Out:
# ['models/mult_30dp_600AMeV_4n_LinearDiscriminantAnalysis.pkl']
