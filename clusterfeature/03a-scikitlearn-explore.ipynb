# %% [markdown]
# # Cluster classification with Scikit-learn classifiers

# %%
import numpy as np
import pandas as pd
import time
import multiprocessing
import functools
from joblib import Parallel, delayed
import sys

import sklearn
from sklearn import *
from sklearn.experimental import enable_hist_gradient_boosting

sys.path.append("..")
from helpers import filename_for

# %% [markdown]
# Load ALL the classification models from scikit-learn.
# Note that some models are very slow to train with large datasets or crash outright, so we give them a reduced number of (shuffled) rows to learn.
# Note that `n_jobs=1` is used, as parallelism is introduced later.

# %%
models_a1 = [
    ('BaggingClassifier', sklearn.ensemble.BaggingClassifier(n_jobs=1), 'medi'),
    ('BernoulliNB', sklearn.naive_bayes.BernoulliNB(), 'fast'),
    ('CalibratedClassifierCV', sklearn.calibration.CalibratedClassifierCV(cv=5), 'medi'),
    ('ComplementNB', sklearn.naive_bayes.ComplementNB(), 'fast'),
    ('GaussianNB', sklearn.naive_bayes.GaussianNB(), 'fast'),
]

models_a2 = [
    ('LinearDiscriminantAnalysis', sklearn.discriminant_analysis.LinearDiscriminantAnalysis(), 'fast'),
    ('LinearSVC', sklearn.svm.LinearSVC(max_iter=200000), 'medi'),  # slow with unscaled data
    ('LogisticRegression', sklearn.linear_model.LogisticRegression(solver='lbfgs', multi_class='auto', max_iter=200000), 'medi'),
    ('LogisticRegressionCV', sklearn.linear_model.LogisticRegressionCV(cv=5, solver='lbfgs', multi_class='auto', max_iter=200000), 'medi'),
    ('MLPClassifier', sklearn.neural_network.MLPClassifier(), 'slow'),
    ('MultinomialNB', sklearn.naive_bayes.MultinomialNB(), 'fast'),
]

models_b = [
    ('NearestCentroid', sklearn.neighbors.NearestCentroid(), 'fast'),
    ('PassiveAggressiveClassifier', sklearn.linear_model.PassiveAggressiveClassifier(max_iter=1000, tol=1e-3, n_jobs=1), 'fast'),
    ('Perceptron', sklearn.linear_model.Perceptron(n_jobs=1), 'fast'),
    ('QuadraticDiscriminantAnalysis', sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis(), 'fast'),
    ('RidgeClassifier', sklearn.linear_model.RidgeClassifier(), 'fast'),
    ('RidgeClassifierCV', sklearn.linear_model.RidgeClassifierCV(), 'fast'),
    ('SGDClassifier', sklearn.linear_model.SGDClassifier(max_iter=5000, tol=1e-3, n_jobs=1), 'fast'),

]

# Run these sequential due to "buffer source array is read-only" with LokyBackend
models_s = [
    ('AdaBoostClassifier', sklearn.ensemble.AdaBoostClassifier(), 'medi'),
    ('DecisionTreeClassifier', sklearn.tree.DecisionTreeClassifier(), 'fast'),  # medi
    ('ExtraTreeClassifier', sklearn.tree.ExtraTreeClassifier(), 'fast'),  # medi
    ('ExtraTreesClassifier', sklearn.ensemble.ExtraTreesClassifier(n_estimators=100, n_jobs=-1), 'fast'),  # medi
    ('RandomForestClassifier', sklearn.ensemble.RandomForestClassifier(n_estimators=100, n_jobs=-1), 'fast'),  # medi
]

# Models that fail alot
models_o = [
    # ('NuSVC', sklearn.svm.NuSVC(), 'fast'),  # nu infeasible 
    ('RadiusNeighborsClassifier', sklearn.neighbors.RadiusNeighborsClassifier(radius=5, n_jobs=-1, outlier_label=0.), 'medi'),
    # ('GaussianProcessClassifier', sklearn.gaussian_process.GaussianProcessClassifier(), 'slow'),
    # ('GradientBoostingClassifier', sklearn.ensemble.GradientBoostingClassifier(), 'slow'),  # crashes
    # ('HistGradientBoostingClassifier', sklearn.ensemble.HistGradientBoostingClassifier(), 'slow'),  # crashes? 
    ('KNeighborsClassifier', sklearn.neighbors.KNeighborsClassifier(n_jobs=2), 'medi'),  # medi
    # ('LabelPropagation', sklearn.semi_supervised.LabelPropagation(), 'slow'),  # requires too much memory to train
    # ('LabelSpreading', sklearn.semi_supervised.LabelSpreading(), 'slow'),  # requires too much memory to train
    ('SVC', sklearn.svm.SVC(gamma='scale'), 'slow'), # slow, not timeouted 
]

# %% [markdown]
# Some models only work with properly scaled data, so we prepare ALL available scalers.

# %%
scalers = [
    # ('Unscaled data', ),
    ("standard scaling", sklearn.preprocessing.StandardScaler()),
    ("min-max scaling", sklearn.preprocessing.MinMaxScaler()),
    ("max-abs scaling", sklearn.preprocessing.MaxAbsScaler()),
    ("robust scaling", sklearn.preprocessing.RobustScaler(quantile_range=(25, 75))),
    # ('power transformation (Yeo-Johnson)', sklearn.preprocessing.PowerTransformer(method='yeo-johnson')),
    # ('power transformation (Box-Cox)', sklearn.preprocessing.PowerTransformer(method='box-cox')), # 'strictly zero' meh.
    ("quantile transformation (gaussian pdf)", sklearn.preprocessing.QuantileTransformer(output_distribution="normal")),
    ("quantile transformation (uniform pdf)", sklearn.preprocessing.QuantileTransformer(output_distribution="uniform")),
    ("sample-wise L2 normalizing", sklearn.preprocessing.Normalizer()),
]

# %% [markdown]
# Train and Test data is passed through the scalers, including the "unscaled" scaler.

# %%
files = [filename_for(15, 30, 600, 500, n, "inclxx", s, "clusterfeature.pkl") for n in [1, 2, 3, 4] for s in range(20)]
dfs = [pd.read_pickle(file) for file in files]
data = pd.concat(dfs, ignore_index=True).sample(frac=1, random_state=1337)

data = data[(abs(data["X"]) < 125) & (abs(data["Y"]) < 125) & (data["T"] < 100)]

print(data["prim"].value_counts())
display(data)
# Out:
# 0.0    8499721
# 1.0    1779876
# Name: prim, dtype: int64
#          i_event  prim          T           E  Size        EToF  EnergyMoment  \
# 3499177   1731.0   1.0  63.755749  149.914871   6.0  607.207764  6.798460e+00
# 8869071   3484.0   0.0  74.362877   15.335159   4.0  580.952515  3.743494e+00
# 2585062   5713.0   0.0  68.605553   37.585819   1.0  600.481689  2.278178e-13
# 2894202   5004.0   0.0  74.553833   34.140911   2.0  625.573181  2.255625e+00
# 3878350   5814.0   0.0  86.484261    7.983827   1.0  264.821777  0.000000e+00
# ...          ...   ...        ...         ...   ...         ...           ...
# 480729    1884.0   0.0  79.410904    2.277636   1.0  296.172211  0.000000e+00
# 3361959   3033.0   1.0  63.699387  613.164795  38.0  609.370972  3.672803e+01
# 7087336   7733.0   0.0  70.274147  246.902069  11.0  568.768555  1.244804e+01
# 8315069   6834.0   0.0  78.157318    2.550865   1.0  425.412720  0.000000e+00
# 1313943   5387.0   0.0  79.691048    2.922474   1.0  387.539795  1.110223e-16
#
#            TSpawn    MaxEHit          X          Y       Z
# 3499177  1.218181  64.293854  -0.682722 -22.500000  1522.5
# 8869071  0.394498   9.338829  37.500000  -1.970521  1757.5
# 2585062  0.000000  37.585819 -76.964607   2.500000  1632.5
# 2894202  0.020336  23.147533  -6.335686  17.500000  1792.5
# 3878350  0.000000   7.983827  98.367348  67.500000  1622.5
# ...           ...        ...        ...        ...     ...
# 480729   0.000000   2.277636 -72.500000 -76.763123  1547.5
# 3361959  5.340049  52.407722   3.392983  12.500000  1522.5
# 7087336  2.275502  52.906334   6.802186  37.500000  1652.5
# 8315069  0.000000   2.550865  41.877541  82.500000  1702.5
# 1313943  0.000000   2.922474  -0.729188 -17.500000  1692.5
#
# [10279597 rows x 12 columns]

# %%
prim1 = data[data["prim"] == 1]
prim0 = data[data["prim"] == 0].sample(n=len(prim1.index), random_state=1337)
balanced_data = pd.concat([prim0, prim1], ignore_index=True).sample(frac=1, random_state=1337)

print(balanced_data["prim"].value_counts())
# Out:
# 1.0    1779876
# 0.0    1779876
# Name: prim, dtype: int64

# %%
msk = np.random.rand(len(balanced_data)) < 0.8
traindata = balanced_data[msk]
testdata = balanced_data[~msk]

print(traindata.shape, testdata.shape)
# Out:
# (2847596, 12) (712156, 12)

# %%
trainscaled = [
    (
        "Unscaled data",
        traindata[["T", "E", "Size", "EToF", "EnergyMoment", "TSpawn", "MaxEHit", "X", "Y", "Z"]],
        testdata[["T", "E", "Size", "EToF", "EnergyMoment", "TSpawn", "MaxEHit", "X", "Y", "Z"]],
    )
] + [
    (
        sname,
        scaler.fit_transform(traindata[["T", "E", "Size", "EToF", "EnergyMoment", "TSpawn", "MaxEHit", "X", "Y", "Z"]]),
        scaler.transform(testdata[["T", "E", "Size", "EToF", "EnergyMoment", "TSpawn", "MaxEHit", "X", "Y", "Z"]]),
    )
    for sname, scaler in scalers
]

# %% [markdown]
# Run all model/scaler combinations, in parallel. Note that we use timeouts per task, as setting at timeout in joblib will throw everything.

# %%
def with_timeout(timeout):
    def decorator(decorated):
        @functools.wraps(decorated)
        def inner(*args, **kwargs):
            pool = multiprocessing.pool.ThreadPool(1)
            async_result = pool.apply_async(decorated, args, kwargs)
            try:
                return async_result.get(timeout)
            except multiprocessing.TimeoutError:
                return

        return inner

    return decorator

# %%
MEDIHEAD = 500000 # 0
SLOWHEAD = 50000 # 0
label = "prim"

y_train_fast = traindata[[label]].values.ravel()
y_train_medi = traindata.head(MEDIHEAD)[[label]].values.ravel()
y_train_slow = traindata.head(SLOWHEAD)[[label]].values.ravel()
y_test = testdata[[label]].values.ravel()


@with_timeout(1200)
def train_model(mname, modelorg, speed, sname, x_train, x_test):
    # These get killed without error?
    if mname == "RadiusNeighborsClassifier" and sname != "Unscaled data":
        return (mname, sname, np.NaN, speed, np.NaN, "Skipped")
    # Too slow
    if mname == "LinearSVC" and (sname == "Unscaled data" or sname == "robust scaling"):
        return (mname, sname, np.NaN, speed, np.NaN, "Skipped")
    try:
        model = sklearn.base.clone(modelorg)
        start = time.time()
        if speed == "slow":
            model.fit(x_train[0:SLOWHEAD], y_train_slow)
        elif speed == "medi":
            model.fit(x_train[0:MEDIHEAD], y_train_medi)
        elif speed == "fast":
            model.fit(x_train, y_train_fast)
        end = time.time()

        y_pred = model.predict(x_test)
        y_true = y_test

        bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)
        return (mname, sname, bac, speed, (end - start), "ok")
    except Exception as err:
        return (mname, sname, np.NaN, speed, np.NaN, err)


def train_model_wrap(mname, modelorg, speed, sname, x_train, x_test):
    ret = train_model(mname, modelorg, speed, sname, x_train, x_test)
    if ret:
        return ret
    else:
        return (mname, sname, np.NaN, speed, np.NaN, "Timeout")

# %%
try:
    results_a1 = Parallel(n_jobs=-1, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
        for sname, x_train, x_test in trainscaled
        for mname, modelorg, speed in models_a1
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 out of  40 | elapsed:    6.7s remaining:    8.2s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:  9.6min finished

# %%
try:
    results_a2 = Parallel(n_jobs=-20, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
        for sname, x_train, x_test in trainscaled
        for mname, modelorg, speed in models_a2
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=-20)]: Using backend LokyBackend with 13 concurrent workers.
# [Parallel(n_jobs=-20)]: Done  48 out of  48 | elapsed:  5.3min finished

# %%
try:
    results_b = Parallel(n_jobs=-1, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
        for sname, x_train, x_test in trainscaled
        for mname, modelorg, speed in models_b
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  50 out of  56 | elapsed:   20.0s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done  56 out of  56 | elapsed:  7.5min finished

# %%
try:
    results_s = Parallel(n_jobs=1, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
        for sname, x_train, x_test in trainscaled
        for mname, modelorg, speed in models_s
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 42.0min finished

# %%
try:
    results_o = Parallel(n_jobs=-1, verbose=1)(
        delayed(train_model_wrap)(mname, modelorg, speed, sname, x_train, x_test)
        for sname, x_train, x_test in trainscaled
        for mname, modelorg, speed in models_o
    )
except Exception as err:
    print(err)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  24 | elapsed:  2.3min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed: 10.0min finished

# %%
def nullhypo():
    y_true = y_test
    y_pred = np.zeros(y_true.shape)

    bac = sklearn.metrics.balanced_accuracy_score(y_true, y_pred)
    return ("Null Hypothesis", "Unscaled data", bac, "fast", 0, "ok")

# %%
results = results_a1 + results_a2 + results_b + results_s + results_o + [nullhypo()]
resultsdf = pd.DataFrame(results)
pd.options.display.max_rows = 999
resultsdf.columns = ["Model", "Scaler", "BAC", "Speed", "Time", "Status"]
resultsdf.sort_values(by=["BAC", "Time", "Model"], ascending=[False, True, True], inplace=True)
#resultsdf.sort_values(by=["Model", "Scaler"], ascending=[True, True], inplace=True)
resultsdf.style.hide_index().format({"BAC": "{:.2%}", "Time": "{:.2f}"}).bar(subset=["BAC"], color="lightgreen").bar(
    subset=["Time"], color="lightblue"
)
# Out:
# <style  type="text/css" >
# #T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow0_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow1_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow2_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow0_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow2_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 19.6%, transparent 19.6%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow1_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow33_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 19.0%, transparent 19.0%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 18.9%, transparent 18.9%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow4_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow5_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow6_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.9%, transparent 99.9%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 19.7%, transparent 19.7%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 19.5%, transparent 19.5%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow7_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 23.9%, transparent 23.9%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow8_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow9_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow10_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow11_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow12_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow13_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.7%, transparent 99.7%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow8_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.8%, transparent 8.8%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow9_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow10_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.5%, transparent 8.5%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow11_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow12_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow15_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.3%, transparent 8.3%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow13_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 7.4%, transparent 7.4%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 6.4%, transparent 6.4%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow15_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow16_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.6%, transparent 99.6%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow16_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow26_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 7.7%, transparent 7.7%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow17_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.4%, transparent 8.4%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.5%, transparent 99.5%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow18_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 27.6%, transparent 27.6%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.4%, transparent 99.4%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow19_col4,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow31_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 7.3%, transparent 7.3%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow20_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 99.3%, transparent 99.3%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow20_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 9.2%, transparent 9.2%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow21_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow22_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.7%, transparent 98.7%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow21_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 24.5%, transparent 24.5%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow22_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 10.6%, transparent 10.6%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow23_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.5%, transparent 98.5%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow23_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 13.8%, transparent 13.8%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow24_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 98.1%, transparent 98.1%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow24_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 13.4%, transparent 13.4%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow25_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow26_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow27_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow28_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow29_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow30_col2,#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow31_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 97.8%, transparent 97.8%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow25_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 6.9%, transparent 6.9%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow27_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 8.0%, transparent 8.0%);
#         }#T_9f18c584_2f32_11eb_a7ca_001999cbc8adrow28_col4,#T
